# %% [markdown]
# # Start coding and Enjoy the journey

# %% [markdown]
# ## Install the repo

# %%
# !git clone --recursive https://github.com/adriazzo/Visual-Place-Recognition-Project.git

# %% [markdown]
# ## Install dependencies

# %%
# %cd Visual-Place-Recognition-Project/image-matching-models
# !pip install -e .[all]

# %%
# !pip install faiss-cpu

# %% [markdown]
# ## Download Datasets

# %%
# %cd /content/Visual-Place-Recognition-Project
# !python download_datasets.py

# %% [markdown]
# ## Run your First VPR Evalutation

# %%
# !python VPR-methods-evaluation/main.py \
--num_workers 8 \
--batch_size 32 \
--log_dir log_dir \
--method=cosplace --backbone=ResNet18 --descriptors_dimension=512 \
--image_size 512 512 \
--database_folder 'data/' \
--queries_folder 'data/' \
--num_preds_to_save 20 \
--recall_values 1 5 10 20 \
--save_for_uncertainty --metric PI

# %% [markdown]
# ## Run Image Matching on Retrieval Results

# %%
# !python match_queries_preds.py \
--preds-dir '<path-to-predictions-folder>' \
--matcher 'superpoint-lg' \
--device 'cuda' \
--num-preds 20

# %% [markdown]
# ## Check Re-ranking Performance

# %%
# !python reranking.py \
--preds-dir '<path-to-predictions-folder>' \
--inliers-dir '<path-to-inliers-folder>' \
--num-preds 20 \
--recall-values 1 5 10 20

# %%
# !python inliers_plot.py \
  --preds-dir '<path-to-predictions-folder>' \
  --inliers-dir '<path-to-inliers-folder>' \
  --positive-dist-threshold 25 \
  --num-preds 20 \
  --output-plots-dir '<path-to-plot-folder>'

# %% [markdown]
# ## Perform Uncertainty Evalutation

# %%
# !python -m vpr_uncertainty.eval \
--preds-dir '<path-to-predictions-folder>' \
--inliers-dir '<path-to-inliers-folder>' \
--z-data-path '<path-to-z-data-file>'
